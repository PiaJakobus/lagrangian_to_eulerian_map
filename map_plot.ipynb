# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import pandas as pd
import itertools
from matplotlib.patches import Circle

# %%
plt.scatter([1,2,4,6,8,10,12,14],np.array([4.111,2.36,1.366,1.162,0.96,0.885,0.801,0.816])/4.111)
plt.plot([1,2,4,6,8,10,12,14],np.array([4.111,2.36,1.366,1.162,0.96,0.885,0.801,0.816])/4.111,label="p18")

plt.scatter([1,2,4,6,8,10,12,14],np.array([18.164,9.552,5.514,3.96,3.924,3.353,3.158,3.28])/18.16)
plt.plot([1,2,4,6,8,10,12,14],np.array([18.164,9.552,5.514,3.96,3.924,3.353,3.158,3.28])/18.164,label="p30")

plt.plot([1,2,4,6,8,10,12,14],np.array([85.416,46.365,25.556,18.409,17.94,15.556,14.184,14.232])/85.416,label="p50")
plt.scatter([1,2,4,6,8,10,12,14],np.array([85.416,46.365,25.556,18.409,17.94,15.556,14.184,14.232])/85.416)


plt.xlabel("# of threads")
plt.ylabel(r"rel. speed up")
plt.legend()
plt.title(r"$14^3$ grid points")
plt.savefig("parallel.png",dpi=200,bbox_inches="tight")

# %%
plt.scatter([1,2,4,6,8,10,12,14],1/(np.array([1.479,0.918,0.538,0.458,0.414,0.3711,0.345,0.35])/1.479))
plt.plot([1,2,4,6,8,10,12,14],1/(np.array([1.479,0.918,0.538,0.458,0.414,0.3711,0.345,0.35])/1.479),label="g10")

plt.scatter([1,2,4,6,8,10,12,14],1/(np.array([4.111,2.36,1.366,1.162,0.96,0.885,0.801,0.816])/4.111))
plt.plot([1,2,4,6,8,10,12,14],1/(np.array([4.111,2.36,1.366,1.162,0.96,0.885,0.801,0.816])/4.111),label="g14")

plt.scatter([1,2,4,6,8,10,12,14],1/(np.array([11.169,6.788,3.861,2.791,2.572,2.316,2.14,2.158])/11.169))
plt.plot([1,2,4,6,8,10,12,14],1/(np.array([11.169,6.788,3.861,2.791,2.572,2.316,2.14,2.158])/11.169),label="g20")

plt.scatter([1,2,4,6,8,10,12,14],1/(np.array([37.539,21.518,12.37,8.669,8.705,7.655,6.935,7.084])/37.539))
plt.plot([1,2,4,6,8,10,12,14],1/(np.array([37.539,21.518,12.37,8.669,8.705,7.655,6.935,7.084])/37.539),label="g30")

plt.xlabel("# of threads")
plt.ylabel(r"rel. speed up")
plt.legend()
plt.title("18$^3$ particles")
plt.savefig("parallel2_speedup.png",dpi=200,bbox_inches="tight")

# %%
data_error_cub = pd.read_csv("error_cub.dat", delim_whitespace=True, header=None)
data_error_quad = pd.read_csv("error_quad.dat", delim_whitespace=True, header=None)
data_error_lin = pd.read_csv("error_lin.dat", delim_whitespace=True, header=None)
data_error_1d = pd.read_csv("error_1d.dat", delim_whitespace=True, header=None)

plt.scatter(np.sqrt(data_error_1d[0]**2 + data_error_1d[1]**2 + data_error_1d[2]**2), data_error_1d[3],s=17,label="zero",color="black")
plt.scatter(np.sqrt(data_error_lin[0]**2 + data_error_lin[1]**2 + data_error_lin[2]**2), data_error_lin[3],s=17,label="lin",color="orange")
plt.scatter(np.sqrt(data_error_quad[0]**2 + data_error_quad[1]**2 + data_error_quad[2]**2), data_error_quad[3],s=17,marker="x",label="quad",color="red")
plt.scatter(np.sqrt(data_error_cub[0]**2 + data_error_cub[1]**2 + data_error_cub[2]**2), data_error_cub[3],s=17,marker = "*",label="cub",color="blue")

plt.ylim(1e-11,0.5e-1)
plt.yscale("log")
plt.title("30 particles")
plt.legend()
#plt.savefig("particles_WC6_p500_noise.pdf")

# %%
data_error_quad = pd.read_csv("error_quad.dat", delim_whitespace=True, header=None)
data_error_lin = pd.read_csv("error_lin.dat", delim_whitespace=True, header=None)
data_error_1d = pd.read_csv("error_1d.dat", delim_whitespace=True, header=None)
data_error_cub = pd.read_csv("error_cub.dat", delim_whitespace=True, header=None)


plt.scatter(np.sqrt(data_error_1d[0]**2 + data_error_1d[1]**2 + data_error_1d[2]**2), data_error_1d[3],s=5,label="pol order 0",color="black")
plt.scatter(np.sqrt(data_error_lin[0]**2 + data_error_lin[1]**2 + data_error_lin[2]**2), data_error_lin[3],s=5,label="pol order 1",color="orange")
plt.scatter(np.sqrt(data_error_quad[0]**2 + data_error_quad[1]**2 + data_error_quad[2]**2), data_error_quad[3],s=4,label="pol order 2",color="red")
#plt.scatter(np.sqrt(data_error_cub[0]**2 + data_error_cub[1]**2 + data_error_cub[2]**2), data_error_cub[3],s=4,label="pol order 3",color="green")

plt.ylim(1e-10,0.5e-1)
plt.yscale("log")
plt.title("300 neighbours, 18 particles, 14 GPs")
plt.legend()
plt.xlabel("radius")
plt.ylabel("rel error")
#plt.savefig("particles_WC6_300neighbs_noise001.png",dpi=120)
# Out:
# Text(0, 0.5, 'rel error')

# %%
data1 = pd.read_csv( 'output.dat', delim_whitespace=True, header=None)
pdim = round(len((np.array(data1)[:,0]))**(1/3)) 

x1 = np.array(data1.iloc[:, 1]).reshape(pdim,pdim,pdim)
y1 = np.array(data1.iloc[:, 2]).reshape(pdim,pdim,pdim)
z1 = np.array(data1.iloc[:, 3]).reshape(pdim,pdim,pdim)
fp = np.array(data1.iloc[:, 4]).reshape(pdim,pdim,pdim)

#plt.scatter(y1[:,:,20],x1[:,:,20],c=fp[:,:,20]**0.0001,s=5)
plt.scatter(y1[20,:,:],x1[20,:,:],c=fp[20,:,:]**0.0001,s=5)

# %%
n =2
ende = -30
fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
cb = ax.scatter(r1[::n], r2[::n], r3[::n], c = fp_p[::n]**0.1,s=2,cmap=cm.seismic, vmin=1e-11, vmax=1e-7)#, marker="x", color="red", s=20)
# ax.set_ylim(-15,15)
#ax.set_xlim(-15,15)
#ax.set_zlim(-15,15)
plt.colorbar(cb,label=r'relative error log')

ax.view_init(45, 40)

# %%
thresh = np.where(fp > 1e-9)

fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
cb = ax.scatter(x1[thresh], y1[thresh], z1[thresh], c = fp[thresh],s=2,cmap=cm.seismic,vmin=5e-10, vmax=1e-5,alpha=1)#,vmin=1e-8,vmax=1e-5)#, marker="x", color="red", s=20)
lim_min = -300
lim_max = 300
ax.set_ylim(lim_min,lim_max)
ax.set_xlim(lim_min,lim_max)
ax.set_zlim(lim_min,lim_max)
plt.colorbar(cb,label=r'mass density')
ax.view_init(45, -20)

# %%
fig = plt.figure()
ax = fig.add_axes([1,1,2,2])

cax = plt.contourf(y1,x1,fp,levels=np.linspace(1e-7,1e-3,200),cmap="magma")
# plt.xlim(-100,100)
# plt.ylim(-50,100)
cbar = fig.colorbar(cax,label=r"$\int$particle mass dz")
cbar.set_ticks([2e-4,4e-4,6e-4])
cbar.set_ticklabels(['2e-4','4e-4','6e-4'])
ax.set_xlabel("y")
ax.set_ylabel("x")
# Out:
# Text(0, 0.5, 'x')

# %%
np.min(r2)
# Out:
# -512.7049863829938

# %%
thresh = np.where(fp > 1e-6)
thresh1 = np.where(fp_p > 1e-6)
thresh3 = np.where(fp_part > 1e-6)


a = 90
b = 0


n =5
ende = -1000
fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
cb = ax.scatter(r1[thresh3][::n], r2[thresh3][::n], r3[thresh3][::n], c = fp_part[thresh3][::n]**0.1,s=2,cmap=cm.hot, vmin=0.2, vmax=0.4)#, marker="x", color="red", s=20)
ax.set_ylim(-250,10)
ax.set_zlim(-5,5)
ax.set_ylim(-270,60)
plt.colorbar(cb,label=r'relative error log')
ax.view_init(a,b)
plt.show()

fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
img = ax.scatter(xx[thresh1], yy[thresh1], zz[thresh1], c=fp_p[thresh1]**0.1, s=2,cmap=plt.hot(), vmin=0.2, vmax=0.4)
fig.colorbar(img)
ax.set_ylim(-250,10)
ax.set_zlim(-5,5)
ax.set_ylim(-270,60)
ax.view_init(a, b)
plt.show()

fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')

img = ax.scatter(x[thresh], y[thresh], z[thresh], c=fp[thresh]**0.1, cmap=plt.hot(), vmin=0.2, vmax=0.4)
ax.set_ylim(-250,10)
ax.set_zlim(-5,5)
ax.set_ylim(-270,60)
fig.colorbar(img)
ax.view_init(a, b)
plt.show()

# %%
a = 90
b = 0

n =5
ende = -1000
fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
cb = ax.scatter(r1[thresh3][::n], r2[thresh3][::n], r3[thresh3][::n], c = fp_part[thresh3][::n]**0.1,s=2,cmap=cm.magma, vmin=0.2, vmax=0.4)#, marker="x", color="red", s=20)
ax.set_xlim(-30,60)
ax.set_zlim(-5,5)
ax.set_ylim(-270,60)
plt.colorbar(cb,label=r'relative error log')
ax.view_init(a,b)
plt.show()



fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
img = ax.scatter(x[thresh], y[thresh], z[thresh], c=fp[thresh]**0.1, cmap=plt.magma(), vmin=0.2, vmax=0.4)
ax.set_xlim(-30,60)
ax.set_zlim(-5,5)
ax.set_ylim(-270,60)
fig.colorbar(img)
ax.view_init(a, b)
plt.show()




thresh5 = np.where(fp_lin > 1e-6) 
#thresh5 = np.where(fp_lin[thresh5] < 0.4) 

fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
img = ax.scatter(x_lin[thresh5], y_lin[thresh5], z_lin[thresh5], c=fp_lin[thresh5]**0.1, cmap=plt.magma(), vmin=0.2, vmax=0.4)
ax.set_xlim(-30,60)
ax.set_zlim(-5,5)
ax.set_ylim(-270,60)
fig.colorbar(img)
ax.view_init(a, b)
plt.show()


thresh6 = np.where(fp_quad > 1e-6)
fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
img = ax.scatter(x_quad[thresh6], y_quad[thresh6], z_quad[thresh6], c=fp_quad[thresh6]**0.1, cmap=plt.magma(), vmin=0.2, vmax=0.4)
ax.set_xlim(-30,60)
ax.set_zlim(-5,5)
ax.set_ylim(-270,60)
fig.colorbar(img)
ax.view_init(a, b)
plt.show()

# %%
#np.nan_to_num(fp_lin,copy=False)
np.max(fp_lin)
# Out:
# 7.436345218828659e+62

# %%
thresh = np.where(fp > 1e-6)
thresh1 = np.where(fp_p > 1e-6)
thresh3 = np.where(fp_part > 1e-6)


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
img = ax.scatter(x[thresh], y[thresh], z[thresh], c=fp[thresh]**0.1, cmap=plt.hot(), vmin=0.2, vmax=0.4)
fig.colorbar(img)
ax.view_init(45, 90)
plt.show()

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
img = ax.scatter(xx[thresh1], yy[thresh1], zz[thresh1], c=fp_p[thresh1]**0.1, s=2,cmap=plt.hot(), vmin=0.2, vmax=0.4)
fig.colorbar(img)
ax.view_init(45, 90)
plt.show()


n =5
ende = -1000
fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
cb = ax.scatter(r1[thresh3][::n], r2[thresh3][::n], r3[thresh3][::n], c = fp_part[thresh3][::n]**0.1,s=2,cmap=cm.hot, vmin=0.2, vmax=0.4)#, marker="x", color="red", s=20)
# ax.set_ylim(-15,15)
#ax.set_xlim(-15,15)
#ax.set_zlim(-15,15)
plt.colorbar(cb,label=r'relative error log')
ax.view_init(45, 90)
plt.show()

# %%
np.where(fp_lin <0)
# Out:
# (array([ 0,  0,  0, ..., 99, 99, 99]),
#  array([ 0,  0,  0, ..., 57, 57, 57]),
#  array([ 2,  3,  4, ..., 42, 67, 68]))

# %%
fig = plt.figure()
ax = fig.add_axes([1,1,2,2])
n = -1
cax = plt.contourf(x_lin[:,-1,:],y_lin[-1,:,:],fp_lin[:,10,:]**0.1,levels=200)#,levels=np.linspace(1e-7,1e-3,200),cmap="magma")
cbar = fig.colorbar(cax,label=r"$\int$particle mass dz")
ax.set_xlabel("y")
ax.set_ylabel("x")
# Out:
# /tmp/ipykernel_6263/2881491593.py:4: RuntimeWarning: invalid value encountered in power
#   cax = plt.contourf(x_lin[:,-1,:],y_lin[-1,:,:],fp_lin[:,10,:]**0.1,levels=200)#,levels=np.linspace(1e-7,1e-3,200),cmap="magma")
# Text(0, 0.5, 'x')

# %%
fig, ax = plt.subplots()
cb = ax.contourf(np.linspace(0,2*np.pi,100), np.linspace(0,np.pi,100),fp_p[50,:,:]**0.01,levels=200)
plt.colorbar(cb)
plt.show()

# %%
fig, ax = plt.subplots(subplot_kw=dict(projection='polar'))
cb = ax.contourf(fp_p[50,:,:].T**0.01,levels=200)
plt.colorbar(cb)
plt.show()

# %%
radius = np.sqrt(x**2 + y**2 + z**2)
theta = np.arccos(z/radius)
phi = np.sign(y) * np.arccos(x/np.sqrt(x**2+y**2))

fig, ax = plt.subplots(subplot_kw=dict(projection='polar'))
cb = ax.contourf(np.linspace(0,2*np.pi,100), np.linspace(0,300,100),fp[:,:,1].T**0.01,levels=200)
plt.colorbar(cb)
plt.show()

# %%
plt.plot(radius[:,50,50],label=el)

# %%
plt.plot(R[:,0,0],fp_p[:,0,0])
plt.plot(radius[:,50,50],fp[:,50,50],ls="--")

plt.yscale("log")

# %%
cax = plt.contourf(fp[:,60,:]**0.1,levels=200)#,levels=np.linspace(1e-7,1e-3,200),cmap="magma")

# %%
cax = plt.contourf(fp_p[0,:,:].T**0.1,levels=200)#,levels=np.linspace(1e-7,1e-3,200),cmap="magma")

#cax = plt.contourf(x[:,-1,:],y[-1,:,:],fp[-1,:,:]**0.01,levels=200)#,levels=np.linspace(1e-7,1e-3,200),cmap="magma")

# %%
# POLAR 
data1 = pd.read_csv( 'mapped_polar.dat', delim_whitespace=True, header=None)
data1 = pd.read_csv( 'mapped_T1_polar4.dat', delim_whitespace=True, header=None)


pdim = round(len((np.array(data1)[:,0]))**(1/3)) 

R = np.array(data1.iloc[:, 1]).reshape(pdim,pdim,pdim)
phi = np.array(data1.iloc[:, 2]).reshape(pdim,pdim,pdim)
theta = np.array(data1.iloc[:, 3]).reshape(pdim,pdim,pdim)
fp_p = np.array(data1.iloc[:, 4]).reshape(pdim,pdim,pdim)


xx = R * np.sin(theta) * np.cos(phi)
yy = R * np.sin(theta) * np.sin(phi)
zz = R * np.cos(theta)

# %%
data1 = pd.read_csv( 'mapped_T1_lin4.dat', delim_whitespace=True, header=None)

pdim = round(len((np.array(data1)[:,0]))**(1/3)) 

x_lin = np.array(data1.iloc[:, 1]).reshape(pdim,pdim,pdim)
y_lin = np.array(data1.iloc[:, 2]).reshape(pdim,pdim,pdim)
z_lin = np.array(data1.iloc[:, 3]).reshape(pdim,pdim,pdim)
fp_lin = np.array(data1.iloc[:, 4]).reshape(pdim,pdim,pdim)




data1 = pd.read_csv( 'mapped_T1_quad4.dat', delim_whitespace=True, header=None)

pdim = round(len((np.array(data1)[:,0]))**(1/3)) 

x_quad = np.array(data1.iloc[:, 1]).reshape(pdim,pdim,pdim)
y_quad = np.array(data1.iloc[:, 2]).reshape(pdim,pdim,pdim)
z_quad = np.array(data1.iloc[:, 3]).reshape(pdim,pdim,pdim)
fp_quad = np.array(data1.iloc[:, 4]).reshape(pdim,pdim,pdim)

# %%
data1 = pd.read_csv( 'mapped_T1.dat', delim_whitespace=True, header=None)
data_error = pd.read_csv("particles_T1.dat", delim_whitespace=True, header=None)


pdim = round(len((np.array(data1)[:,0]))**(1/3)) 
#gdim = round(len((np.array(data_error)[:,0]))**(1/3)) 

x = np.array(data1.iloc[:, 1]).reshape(pdim,pdim,pdim)
y = np.array(data1.iloc[:, 2]).reshape(pdim,pdim,pdim)
z = np.array(data1.iloc[:, 3]).reshape(pdim,pdim,pdim)
fp = np.array(data1.iloc[:, 4]).reshape(pdim,pdim,pdim)

radius = np.sqrt(x**2 + y**2 + z**2)
theta1 = np.arccos(z/radius)
phi1 = np.sign(y) * np.arccos(x/np.sqrt(x**2+y**2))


r1 = np.array(data_error.iloc[:, 1])
r2 = np.array(data_error.iloc[:, 2])
r3 = np.array(data_error.iloc[:, 3])
fp_part = np.array(data_error.iloc[:, 4])

# %%
n =1
ende = -1
fig = plt.figure(figsize=(10,10))
#ax = fig.add_axes([1,1,1,1])
ax = plt.axes(projection='3d')
#ax.scatter(x1, y1, z1, c=fp,s=0.1)
cb = ax.scatter(r1[0:ende:n,0:ende:n,0:ende:n], r2[0:ende:n,0:ende:n,0:ende:n], r3[0:ende:n,0:ende:n,0:ende:n], c = err[0:ende:n,0:ende:n,0:ende:n]**1,s=20,cmap=cm.coolwarm)#, marker="x", color="red", s=20)
k = 5
ax.scatter(r1[0:ende:n,0:ende:n,k], r2[0:ende:n,0:ende:n,k], r3[0:ende:n,0:ende:n,k], c="red",s=50)

plt.colorbar(cb,label=r'relative error log')
ax.view_init(180, 180)

# %%
ax = plt.axes(projection='3d')
ax.scatter(r1,r2,r3, c=err**0.0000005,s=50,alpha=0.8)
ax.view_init(10, 10)

# %%
i=1
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
circle=Circle((x1[i], y1[i]), 0.5,linewidth=1,edgecolor='black', facecolor='None')
ax.add_patch(circle)
plt.show()
