# %%
data_error = pd.read_csv("error_quad.dat", delim_whitespace=True, header=None)
data_error_lin = pd.read_csv("error_lin.dat", delim_whitespace=True, header=None)
data_error_1d = pd.read_csv("error_1d.dat", delim_whitespace=True, header=None)

plt.scatter(np.sqrt(data_error_1d[0]**2 + data_error_1d[1]**2 + data_error_1d[2]**2), data_error_1d[3],s=17,label="pol order 0",color="black")
plt.scatter(np.sqrt(data_error_lin[0]**2 + data_error_lin[1]**2 + data_error_lin[2]**2), data_error_lin[3],s=17,label="pol order 1",color="orange")
plt.scatter(np.sqrt(data_error[0]**2 + data_error[1]**2 + data_error[2]**2), data_error[3],s=17,label="pol order 2",color="red")
plt.ylim(1e-11,0.5e-1)
plt.yscale("log")
plt.title("30 particles")
plt.legend()
plt.savefig("particles_WC6_500p_noise.pdf")

# %%
data_error = pd.read_csv("error_quad.dat", delim_whitespace=True, header=None)
data_error_lin = pd.read_csv("error_lin.dat", delim_whitespace=True, header=None)
data_error_1d = pd.read_csv("error_1d.dat", delim_whitespace=True, header=None)

plt.scatter(np.sqrt(data_error_1d[0]**2 + data_error_1d[1]**2 + data_error_1d[2]**2), data_error_1d[3],s=17,label="pol order 0",color="black")
plt.scatter(np.sqrt(data_error_lin[0]**2 + data_error_lin[1]**2 + data_error_lin[2]**2), data_error_lin[3],s=17,label="pol order 1",color="orange")
plt.scatter(np.sqrt(data_error[0]**2 + data_error[1]**2 + data_error[2]**2), data_error[3],s=17,label="pol order 2",color="red")
plt.ylim(1e-8,0.5e-1)
plt.yscale("log")
plt.title("30 particles")
plt.legend()
plt.savefig("particles_WC6_p30_noise.pdf")

# %%
data_error = pd.read_csv("error_quad.dat", delim_whitespace=True, header=None)
data_error_lin = pd.read_csv("error_lin.dat", delim_whitespace=True, header=None)
data_error_1d = pd.read_csv("error_1d.dat", delim_whitespace=True, header=None)

plt.scatter(np.sqrt(data_error_1d[0]**2 + data_error_1d[1]**2 + data_error_1d[2]**2), data_error_1d[3],s=17,label="pol order 0",color="black")
plt.scatter(np.sqrt(data_error_lin[0]**2 + data_error_lin[1]**2 + data_error_lin[2]**2), data_error_lin[3],s=17,label="pol order 1",color="orange")
plt.scatter(np.sqrt(data_error[0]**2 + data_error[1]**2 + data_error[2]**2), data_error[3],s=17,label="pol order 2",color="red")
plt.ylim(1e-9,0.5e-1)
plt.yscale("log")
plt.title("30 particles, M4")
plt.legend()
plt.savefig("particles_noise.pdf")

# %%
data_error1 = pd.read_csv("error1.dat", delim_whitespace=True, header=None)
data_error2 = pd.read_csv("error2.dat", delim_whitespace=True, header=None)
data_error3 = pd.read_csv("error3.dat", delim_whitespace=True, header=None)

plt.scatter(np.sqrt(data_error3[0]**2 + data_error3[1]**2 + data_error3[2]**2), data_error3[3],s=17,label="pol order 0",color="orange")
plt.scatter(np.sqrt(data_error1[0]**2 + data_error1[1]**2 + data_error1[2]**2), data_error1[3],s=17,label="pol order 1",color="black")
plt.scatter(np.sqrt(data_error2[0]**2 + data_error2[1]**2 + data_error2[2]**2), data_error2[3],s=17,label="pol order 2",color="red")

plt.ylim(1e-8,3e-1)
plt.yscale("log")
plt.title("20 particles")
plt.legend()

# %%
data_error1 = pd.read_csv("error1.dat", delim_whitespace=True, header=None)
data_error2 = pd.read_csv("error2.dat", delim_whitespace=True, header=None)
data_error3 = pd.read_csv("error3.dat", delim_whitespace=True, header=None)

plt.scatter(np.sqrt(data_error3[0]**2 + data_error3[1]**2 + data_error3[2]**2), data_error3[3],s=17,label="pol order 0",color="orange")
plt.scatter(np.sqrt(data_error1[0]**2 + data_error1[1]**2 + data_error1[2]**2), data_error1[3],s=17,label="pol order 1",color="black")
plt.scatter(np.sqrt(data_error2[0]**2 + data_error2[1]**2 + data_error2[2]**2), data_error2[3],s=17,label="pol order 2",color="red")

plt.ylim(1e-8,3e-1)
plt.yscale("log")
plt.title("20 particles")
plt.legend()

# %%
data_error_1d = pd.read_csv("error00.dat", delim_whitespace=True, header=None)
data_error_lin = pd.read_csv("error11.dat", delim_whitespace=True, header=None)
data_error_quad = pd.read_csv("error22.dat", delim_whitespace=True, header=None)

plt.scatter(np.sqrt(data_error_1d[0]**2 + data_error_1d[1]**2 + data_error_1d[2]**2), data_error_1d[3],s=17,label="pol order 0",color="black")
plt.scatter(np.sqrt(data_error_lin[0]**2 + data_error_lin[1]**2 + data_error_lin[2]**2), data_error_lin[3],s=20,marker="d",label="pol order 1",color="red")
plt.scatter(np.sqrt(data_error_quad[0]**2 + data_error_quad[1]**2 + data_error_quad[2]**2), data_error_quad[3],s=15,marker = "*",label="pol order 2",color="green")
plt.ylim(1e-5,3e-1)
plt.yscale("log")
plt.legend()
#plt.title("QUAD P50, G10, Noise0")

# %%
data_error_quad = pd.read_csv("error_new1.dat", delim_whitespace=True, header=None)
data_error_lin = pd.read_csv("error_new2.dat", delim_whitespace=True, header=None)
data_error_lin2 = pd.read_csv("error_new22.dat", delim_whitespace=True, header=None)
data_error_1d = pd.read_csv("error_new3.dat", delim_whitespace=True, header=None)


plt.scatter(np.sqrt(data_error_1d[0]**2 + data_error_1d[1]**2 + data_error_1d[2]**2), data_error_1d[3],s=15,marker = "d",label="pol order 0",color="black")
plt.scatter(np.sqrt(data_error_lin[0]**2 + data_error_lin[1]**2 + data_error_lin[2]**2), data_error_lin[3],s=15,marker = "x",label="pol order 1 no SVD",color="red")
plt.scatter(np.sqrt(data_error_lin2[0]**2 + data_error_lin2[1]**2 + data_error_lin2[2]**2), data_error_lin2[3],s=15,marker = "x",label="pol order 1 only SVD",color="orange")
plt.scatter(np.sqrt(data_error_quad[0]**2 + data_error_quad[1]**2 + data_error_quad[2]**2), data_error_quad[3],s=10,label="pol order 2", color="blue")

plt.yscale("log")
#plt.ylim(1e-3,1)
plt.title("10p, 9g,0f")
plt.xlabel("radius r")
plt.ylabel(r"$\log_{10}$ (err)")
plt.legend(frameon=False)
plt.savefig("comparison5.pdf")

# %%
data_error_quad = pd.read_csv("error_quad3.dat", delim_whitespace=True, header=None)
data_error_lin = pd.read_csv("error_lin3.dat", delim_whitespace=True, header=None)
data_error_lin2 = pd.read_csv("error_lin33.dat", delim_whitespace=True, header=None)
data_error_1d = pd.read_csv("error_1d3.dat", delim_whitespace=True, header=None)


plt.scatter(np.sqrt(data_error_1d[0]**2 + data_error_1d[1]**2 + data_error_1d[2]**2), data_error_1d[3],s=15,marker = "d",label="pol order 0",color="black")
plt.scatter(np.sqrt(data_error_lin[0]**2 + data_error_lin[1]**2 + data_error_lin[2]**2), data_error_lin[3],s=15,marker = "x",label="pol order 1 SVD",color="red")
plt.scatter(np.sqrt(data_error_lin2[0]**2 + data_error_lin2[1]**2 + data_error_lin2[2]**2), data_error_lin2[3],s=15,marker = "x",label="pol order 1 both",color="orange")
plt.scatter(np.sqrt(data_error_quad[0]**2 + data_error_quad[1]**2 + data_error_quad[2]**2), data_error_quad[3],s=10,label="pol order 2", color="blue")

plt.yscale("log")
#plt.ylim(2e-4,0.006)
plt.title("45p, 9g,0f")
plt.xlabel("radius r")
plt.ylabel(r"$\log_{10}$ (err)")
plt.legend()
plt.savefig("comparison4.pdf")

# %%
data_error_quad = pd.read_csv("error_quad2.dat", delim_whitespace=True, header=None)
data_error_lin = pd.read_csv("error_lin2.dat", delim_whitespace=True, header=None)
data_error_1d = pd.read_csv("error_1d2.dat", delim_whitespace=True, header=None)


plt.scatter(np.sqrt(data_error_1d[0]**2 + data_error_1d[1]**2 + data_error_1d[2]**2), data_error_1d[3],s=15,marker = "d",label="pol order 0",color="black")
plt.scatter(np.sqrt(data_error_lin[0]**2 + data_error_lin[1]**2 + data_error_lin[2]**2), data_error_lin[3],s=15,marker = "x",label="pol order 1",color="red")
plt.scatter(np.sqrt(data_error_quad[0]**2 + data_error_quad[1]**2 + data_error_quad[2]**2), data_error_quad[3],s=10,label="pol order 2", color="blue")

plt.yscale("log")
plt.ylim(2e-7,-2.8)
plt.title("100p, 10g,0.1f")
plt.xlabel("radius r")
plt.ylabel(r"$\log_{10}$ (err)")
plt.legend()
plt.savefig("comparison3.pdf")
# Out:
# /tmp/ipykernel_1717552/977556917.py:11: UserWarning: Attempted to set non-positive top ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim(2e-7,-2.8)

# %%
data_error_quad = pd.read_csv("error_quad1.dat", delim_whitespace=True, header=None)
data_error_lin = pd.read_csv("error_lin1.dat", delim_whitespace=True, header=None)
data_error_1d = pd.read_csv("error_1d1.dat", delim_whitespace=True, header=None)


plt.scatter(np.sqrt(data_error_1d[0]**2 + data_error_1d[1]**2 + data_error_1d[2]**2), data_error_1d[3],s=15,marker = "d",label="pol order 0",color="black")
plt.scatter(np.sqrt(data_error_lin[0]**2 + data_error_lin[1]**2 + data_error_lin[2]**2), data_error_lin[3],s=15,marker = "x",label="pol order 1",color="red")
plt.scatter(np.sqrt(data_error_quad[0]**2 + data_error_quad[1]**2 + data_error_quad[2]**2), data_error_quad[3],s=10,label="pol order 2", color="blue")

plt.yscale("log")
plt.ylim(2e-5,-2.8)
plt.title("100p, 20g,0f")
plt.xlabel("radius r")
plt.ylabel(r"$\log_{10}$ (err)")
plt.legend()
plt.savefig("comparison2.pdf")
# Out:
# /tmp/ipykernel_1717552/1507101426.py:11: UserWarning: Attempted to set non-positive top ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim(2e-5,-2.8)

# %%
data_error_quad = pd.read_csv("error_quad.dat", delim_whitespace=True, header=None)
data_error_lin = pd.read_csv("error_lin.dat", delim_whitespace=True, header=None)
data_error_1d = pd.read_csv("error_1d.dat", delim_whitespace=True, header=None)


plt.scatter(np.sqrt(data_error_1d[0]**2 + data_error_1d[1]**2 + data_error_1d[2]**2), data_error_1d[3],s=15,marker = "d",label="pol order 0",color="black")
plt.scatter(np.sqrt(data_error_lin[0]**2 + data_error_lin[1]**2 + data_error_lin[2]**2), data_error_lin[3],s=15,marker = "x",label="pol order 1",color="red")
plt.scatter(np.sqrt(data_error_quad[0]**2 + data_error_quad[1]**2 + data_error_quad[2]**2), data_error_quad[3],s=10,label="pol order 2", color="blue")

plt.yscale("log")
plt.ylim(2e-5,-2.8)
plt.title("Comparison")
plt.xlabel("radius r")
plt.ylabel(r"$\log_{10}$ (err)")
plt.legend()
plt.savefig("comparison.pdf")
# Out:
# /tmp/ipykernel_1717552/1217499299.py:11: UserWarning: Attempted to set non-positive top ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim(2e-5,-2.8)

# %%
data_error_quad = pd.read_csv("error_quad.dat", delim_whitespace=True, header=None)
data_error_lin = pd.read_csv("error_lin.dat", delim_whitespace=True, header=None)
data_error_1d = pd.read_csv("error_1d.dat", delim_whitespace=True, header=None)


plt.scatter(np.sqrt(data_error_quad[0]**2 + data_error_quad[1]**2 + data_error_quad[2]**2), data_error_quad[3],s=10,label="pol order 2", color="blue")
plt.scatter(np.sqrt(data_error_lin[0]**2 + data_error_lin[1]**2 + data_error_lin[2]**2), data_error_lin[3],s=5,marker = "x",label="pol order 1",color="red")
plt.scatter(np.sqrt(data_error_1d[0]**2 + data_error_1d[1]**2 + data_error_1d[2]**2), data_error_1d[3],s=5,label="pol order 0",color="black")

plt.yscale("log")
plt.ylim(2e-5,-2.8)
plt.title("Comparison")
plt.xlabel("radius r")
plt.ylabel(r"$\log_{10}$ (err)")
plt.legend()
# Out:
# /tmp/ipykernel_1717552/699291916.py:11: UserWarning: Attempted to set non-positive top ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim(2e-5,-2.8)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import pandas as pd
import itertools
from matplotlib.patches import Circle


data1_quad = pd.read_csv( 'particles_lin.dat', delim_whitespace=True, header=None)
data_error_quad = pd.read_csv("error_lin.dat", delim_whitespace=True, header=None)


pdim = round(len((np.array(data1)[:,0]))**(1/3)) 
gdim = round(len((np.array(data_error)[:,0]))**(1/3)) 

x1 = np.array(data1.iloc[:, 1]).reshape(pdim,pdim,pdim)
y1 = np.array(data1.iloc[:, 2]).reshape(pdim,pdim,pdim)
z1 = np.array(data1.iloc[:, 3]).reshape(pdim,pdim,pdim)
fp = np.array(data1.iloc[:, 4]).reshape(pdim,pdim,pdim)

r1 = np.array(data_error.iloc[:, 0]).reshape(gdim,gdim,gdim)
r2 = np.array(data_error.iloc[:, 1]).reshape(gdim,gdim,gdim)
r3 = np.array(data_error.iloc[:, 2]).reshape(gdim,gdim,gdim)
err = np.array(data_error.iloc[:, 3]).reshape(gdim,gdim,gdim)


fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.set_aspect('equal')
cb = plt.scatter(y1[:,:,-1],x1[:,:,-1],c=fp[:,:,-1],s=30)
plt.scatter(r1[:,-1,:],r3[:,-1,:],marker="x",color="red",s=100)


plt.colorbar(cb,label=r'$\exp(-r_i^2)$')
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.xlim(-1,1)
plt.ylim(-1,1)
# Out:
# (-1.0, 1.0)

# %%
for el in np.arange(10):
    for k in np.arange(10):
        plt.plot(r1[:,el,k],err[:,el,k])
        #plt.plot(r1[:,el,0],err[:,el,k])
plt.ylim(1e-5,10)
plt.yscale("log")

# %%
laenge = len(r2[0,:,0])
for j in np.arange(0,len(r2[0,:,0]),1): 
    #for j in np.arange(0,len(r2[0,:,0]),5): 
    i = 0
    fig, ax = plt.subplots()
    #fig = plt.figure()
    #ax = fig.add_axes([1,1,1,1])
    ax.set_aspect('equal')
    cb = ax.contourf(r2[i,:,j],r2[i,:,j],np.log10(err[:,j,:]),alpha=0.7,cmap="rainbow")#,levels=np.linspace(-7,-3,100))
    #ax.contourf(r2[0,:,0],r2[0,:,0],err[0,:,:],alpha=0.7,cmap="Reds_r",levels=np.linspace(0.1,1000,100))

    #ax.scatter(r1[:,:,0],r2[:,:,0], marker='x', s=30, color='red')

    #plt.colorbar(cb,label=r'relative error log')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title("i=%.0f, j=%.0f (%.0f)"%(i ,j, laenge))
    plt.savefig("plots/2D_%s.png"%j,dpi=150)

# %%
r1[::10,::10,0]
# Out:
# array([[0.00034309, 0.00077819],
#        [0.00077819, 0.00044556]])

# %%
n = 10
for n in np.arange(0,np.size(err[0,0,:]),5):
    fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
    ax.plot_surface(r1[:,:,n], r2[:,:,n], err[:,:,n], cmap=cm.coolwarm)
    ax.set_title(n)
    ax.view_init(40, 20)
    #ax.set_zlim(0.0001,0.0006)
    plt.savefig("plots/3D_ansicht%d.png"%n,dpi=150)

# %%
n =1
ende = -1
fig = plt.figure(figsize=(10,10))
#ax = fig.add_axes([1,1,1,1])
ax = plt.axes(projection='3d')
#ax.scatter(x1, y1, z1, c=fp,s=0.1)
cb = ax.scatter(r1[0:ende:n,0:ende:n,0:ende:n], r2[0:ende:n,0:ende:n,0:ende:n], r3[0:ende:n,0:ende:n,0:ende:n], c = err[0:ende:n,0:ende:n,0:ende:n]**1,s=20,cmap=cm.coolwarm)#, marker="x", color="red", s=20)
k = 17
ax.scatter(r1[0:ende:n,0:ende:n,k], r2[0:ende:n,0:ende:n,k], r3[0:ende:n,0:ende:n,k], c="red",s=50)

plt.colorbar(cb,label=r'relative error log')
ax.view_init(180, 180)

# %%
ax = plt.axes(projection='3d')
ax.scatter(r1,r2,r3, c=err**0.0000005,s=50,alpha=0.8)
ax.view_init(10, 10)

# %%
i=1
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
circle=Circle((x1[i], y1[i]), 0.5,linewidth=1,edgecolor='black', facecolor='None')
ax.add_patch(circle)
plt.show()
